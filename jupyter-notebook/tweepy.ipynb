# %%
import tweepy
import matplotlib.pyplot as plt
from textblob import TextBlob
import time

# %%
access_token = "266449908-riSJfN9LFhHcRlm2NNkaA2EA30JGHEZf5rBnJPZR";
access_sec = "BZVZx7nxSAYbsYkpCnPQLpVVlQyFMFIaZ2T49vSbPFasE";
consumer_key = "kZADq17e01p6ILN0u3vdgU1DH";
consumer_sec = "7bKnY3aGD1LZIDWbS6tVzru8zFZNV492oN9I51g7b6HctxC8Kb";

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)
auth.set_access_token(access_token,access_sec)

# %%
api_connect = tweepy.API(auth)

# %%
tweet_data = api_connect.search("virat kohli", count = 100)

# %%
pos =0 
neg =0
neu =0


for tweet in tweet_data:
  #print(tweet_data)
  analysis = TextBlob(tweet.text) #here it wil aply NLP
  print(analysis.sentiment)
  
  #now checking polarity only
  if analysis.sentiment.polarity>0:
    print("positive")
    pos=pos+1
  elif analysis.sentiment.polarity == 0:
    print("neutral")
    neu=neu=1
  else :
    print("negative")
    neg=neg+1

    #plotiing graph 
#plt.xlabel("tags")
#plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[pos,neu,neg])
plt.pie([pos,neg,neu],labels = ["pos","neg","neu"],autopct = "%1.1f%%")
plt.show()
# Out:
# Sentiment(polarity=0.875, subjectivity=0.7)
# positive
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# negative
# Sentiment(polarity=0.25, subjectivity=0.75)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
# Sentiment(polarity=0.55, subjectivity=1.0)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=-0.2, subjectivity=0.4)
# negative
# Sentiment(polarity=0.25, subjectivity=0.575)
# positive
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
# Sentiment(polarity=-0.3499999999999999, subjectivity=0.8333333333333333)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# ...
