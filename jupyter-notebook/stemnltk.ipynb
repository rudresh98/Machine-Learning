# %%
from nltk import stem
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import time

# %%
port = PorterStemmer()

# %%
dir(stem)

# %%
for i in ['going','goes','gone','car','intelligent','intelligence','feet','foot']:
  print(port.stem(i))
  time.sleep(1)
# Out:
# go
# goe
# gone
# car
# intellig
# intellig
# feet
# foot
