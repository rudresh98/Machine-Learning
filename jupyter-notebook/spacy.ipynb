# %%
import spacy

# %%
nlp = spacy.load('en')

# %%
data = "hello i  am the world playing cricket my"

# %%
new_data = nlp(data) #automatic tokenize

# %%
for i in new_data:
  print("lemma-->",i,i.lemma_)
  print("----------------")
  print(i,"POS",i.pos_)
# Out:
# lemma--> hello hello
# ----------------
# hello POS INTJ
# lemma--> i i
# ----------------
# i POS PRON
# lemma-->
# ----------------
#   POS SPACE
# lemma--> am be
# ----------------
# am POS VERB
# lemma--> the the
# ----------------
# the POS DET
# lemma--> world world
# ----------------
# world POS NOUN
# lemma--> playing playing
# ----------------
# playing POS NOUN
# lemma--> cricket cricket
# ----------------
# cricket POS NOUN
# lemma--> my -PRON-
# ----------------
# my POS DET
